# %%
#1
number=range(100,1001)
sum=0
for i in number:
    sum=sum+i
print(sum)
# Out:
# 495550

# %%
#2
import numpy as np
number= range(100,1001)
print(np.sum(number))
# Out:
# 495550

# %%
#3
random= np.random.normal(0,1,50)
print(random)
# with np.random.normal(), the variables change everytime
# Out:
# [ 0.26548859  0.64329145  0.66297018 -1.07519236  0.57607545 -0.69211787
#  -0.71747418  1.37435044  0.63863314 -2.4368313   0.28709124 -1.71264523
#   0.67929064  0.93830692 -0.54461877  0.55609575 -0.36271207 -1.57258617
#  -0.77038276 -0.14716362  0.28890688  0.71576112  0.29839269  1.34404064
#   0.47501582  0.05877762  1.85823313  0.4083651  -0.18124302  0.21564783
#  -0.6574687   1.97550551 -0.85968953  0.13525209  0.19955655 -0.6227573
#  -0.03893012  0.73167821  0.48884586 -0.29820517 -0.91899761 -0.69832683
#  -0.95318495  0.40185198  0.43130852 -0.58407688  0.80793863  1.06271796
#   1.27635396  0.52112185]

# %%
np.random.seed(10); random= np.random.normal(0,1,50)

# This is because it randomly generates numbers so it changes everytime 

print(np.std(random)) # after adding the seed(), the same variables appear everytime
# Out:
# 0.9009602327711386

# %%
#4
dataMat= np.array(np.random.uniform(size=[10,50]))
print(dataMat)
dataMat.shape
# Out:
# [[0.98762547 0.45630455 0.82612284 0.25137413 0.59737165 0.90283176
#   0.53455795 0.59020136 0.03928177 0.35718176 0.07961309 0.30545992
#   0.33071931 0.7738303  0.03995921 0.42949218 0.31492687 0.63649114
#   0.34634715 0.04309736 0.87991517 0.76324059 0.87809664 0.41750914
#   0.60557756 0.51346663 0.59783665 0.26221566 0.30087131 0.02539978
#   0.30306256 0.24207588 0.55757819 0.56550702 0.47513225 0.29279798
#   0.06425106 0.97881915 0.33970784 0.49504863 0.97708073 0.44077382
#   0.31827281 0.51979699 0.57813643 0.85393375 0.06809727 0.46453081
#   0.78194912 0.71860281]
#  [0.58602198 0.03709441 0.35065639 0.56319068 0.29972987 0.51233415
#   0.67346693 0.15919373 0.05047767 0.33781589 0.10806377 0.17890281
#   0.8858271  0.36536497 0.21876935 0.75249617 0.10687958 0.74460324
#   0.46978529 0.59825567 0.14762019 0.18403482 0.64507213 0.04862801
#   0.24861251 0.54240852 0.22677334 0.38141153 0.92223279 0.92535687
# ...

# %%
np.sum(datamat)
# Out:
# 247.55319533781312

# %%
column_sum=np.sum(dataMat,axis=0)
print('Sum of each column:\n', column_sum)
# Out:
# Sum of each column:
#  [5.14448378 5.81148837 5.95659182 4.88833687 4.08698348 6.05041353
#  4.81816548 4.55081569 5.54202651 5.70521103 5.52145488 4.75852688
#  6.55977573 3.57407621 6.57377057 3.28852598 4.55331662 4.55587492
#  4.03289923 3.96019091 4.28601962 5.80314482 4.68177428 5.34892163
#  7.11771704 6.2821576  6.62047343 6.1100005  3.27470277 4.30782195
#  4.83979994 3.40042597 4.05437909 3.75634568 5.2806136  5.44528993
#  2.51212448 4.74892135 5.86965217 5.02298147 3.70763807 6.57200418
#  4.46632791 5.40207301 4.17997112 4.98818206 5.28014592 4.445171
#  4.58739965 5.22808661]

# %%
row_sum=np.sum(datamat,axis=1)
print('Sum of each row: \n', row_sum)
# Out:
# Sum of each row:
#  [22.21928202 22.19567451 27.33108215 24.85831708 30.20598614 25.05809409
#  25.31090688 27.26159659 19.37313394 23.73912193]

# %%
sum_of_all= np.sum(datamat)
print('Total sum of all variables is: ', sum_of_all)
# Out:
# Total sum of all variables is:  247.55319533781312

# %%
#5

# %%
result1=[]
result2=[]
result3=[]
mean=0
std=1

for _ in range(1000):
    y=np.random.normal(mean,std,10)
    z=np.random.normal(mean,std,25)
    h=np.random.normal(mean,std,100)
    result1.append(np.mean(y))
    result2.append(np.mean(z))
    result3.append(np.mean(h))
print('The mean for sample size 10 is',np.mean(result1))
print('The standard deviation for sample size 10 is',np.std(result1))
print('The mean for sample size 25 is',np.mean(result2))
print('The standard deviation for sample size 25 is',np.std(result2))
print('The mean for sample size 100 is',np.mean(h))
print('The standard deviation for sample size 100 is',np.std(h))
print(len(result1))
# Out:
# The mean for sample size 10 is 0.00202604767710615
# The standard deviation for sample size 10 is 0.30572446493038874
# The mean for sample size 25 is 0.00807846951210566
# The standard deviation for sample size 25 is 0.20476580498827032
# The mean for sample size 100 is -0.10756302649175448
# The standard deviation for sample size 100 is 0.9155428316774248
# 1000
